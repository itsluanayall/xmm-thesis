# %%
import requests
import pandas as pd
import os
import tarfile
import logging
import shutil
logging.basicConfig(level=logging.INFO)

DOWNLOAD_ODFS = False   #if you need to download the odfs, set to 'True'

# %% [markdown]
# Read the csv file downloaded from the XSA, in which all the Markarian421 ObsId are listed.

# %%
file_csv = pd.read_csv('NXSA-Results-1585319865076.csv')
ids = file_csv['OBSERVATION.OBSERVATION_ID']

# %% [markdown]
# Define a download function with python's request module.

# %%
def download(url, file_name):
    with open(file_name, "wb") as file:
        # get request
        response = requests.get(url)
        # write to file
        file.write(response.content)

# %% [markdown]
# Define a function that creates the structure for all the folders containing the data.

# %%
def make_dir_structure(ObsId):
    if not os.path.exists(ObsId):
        logging.info(f'Creating the directory structure for the data {ObsId}.')
        
        #make the ObsId main folder
        os.mkdir(ObsId)
        
        #make the subfolders that will go in the ObsId folder
        subfolders = ['rgs', 'odf' ]
        for folder in subfolders:
            os.mkdir(os.path.join(ObsId, folder))
        logging.info('Structure completed!')
        
    else:
        logging.info(f'Folder structure for {ObsId} already OK.')

# %% [markdown]
# Define an unpacking function to extract the ODF file in the tar.gz format.

# %%
def unpack(tar_name, odf_directory):
    if not os.path.exists(odf_directory):
        os.mkdir(odf_directory)
        
    #Extract tar.gz containing the ODF   
    try:
        with tarfile.open(tar_name, "r:gz") as tar:
            tar.extractall(path=odf_directory)

        #Extract the additional tar files inside the previous tar.gz
        for file in os.listdir(odf_directory):
            if file.endswith('.TAR'):
                with tarfile.open(os.path.join(odf_directory,file), "r") as tar:
                    tar.extractall(path=odf_directory)
        logging.info(f'All ODFs for {tar_name} have been extracted!')
        
    except Exception as e:
        logging.error(f'An error has occurred with tar {tar_name}.')
        dir_name = tar_name.split('.')[0]
        shutil.rmtree(dir_name) #removes the observation that 
        logging.debug(str(e))

# %% [markdown]
# Generate the URLs to download the ODF for each observation. Notice that the ObsId must be 10 characters in the URL, so if it is less, we add zeros to the ID.

# %%
ids_list = ids.tolist()
ids_zerofill = []

for ObsId in ids_list:
    ids_zerofill.append(str(ObsId).zfill(10))

    
for ObsId in ids_zerofill:
    
    if DOWNLOAD_ODFS:
        url = f"http://nxsa.esac.esa.int/nxsa-sl/servlet/data-action-aio?obsno={ObsId}&level=ODF"
        download(url, f"{ObsId}.tar.gz")
    
    make_dir_structure(ObsId)
    unpack(f'{ObsId}.tar.gz', os.path.join(ObsId, 'odf'))
# Out:
# INFO:root:Folder structure for 0099280101 already OK.
# INFO:root:All ODFs for 0099280101.tar.gz have been extracted!
# INFO:root:Folder structure for 0099280201 already OK.
# INFO:root:All ODFs for 0099280201.tar.gz have been extracted!
# INFO:root:Folder structure for 0099280301 already OK.
# INFO:root:All ODFs for 0099280301.tar.gz have been extracted!
# INFO:root:Folder structure for 0099280401 already OK.
# INFO:root:All ODFs for 0099280401.tar.gz have been extracted!
# INFO:root:Folder structure for 0099280501 already OK.
# INFO:root:All ODFs for 0099280501.tar.gz have been extracted!
# INFO:root:Folder structure for 0099280601 already OK.
# INFO:root:All ODFs for 0099280601.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540101 already OK.
# INFO:root:All ODFs for 0136540101.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540201 already OK.
# INFO:root:All ODFs for 0136540201.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540301 already OK.
# INFO:root:All ODFs for 0136540301.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540401 already OK.
# INFO:root:All ODFs for 0136540401.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540501 already OK.
# INFO:root:All ODFs for 0136540501.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540601 already OK.
# INFO:root:All ODFs for 0136540601.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540701 already OK.
# INFO:root:All ODFs for 0136540701.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540801 already OK.
# INFO:root:All ODFs for 0136540801.tar.gz have been extracted!
# INFO:root:Folder structure for 0136540901 already OK.
# INFO:root:All ODFs for 0136540901.tar.gz have been extracted!
# INFO:root:Folder structure for 0150498701 already OK.
# INFO:root:All ODFs for 0150498701.tar.gz have been extracted!
# INFO:root:Folder structure for 0153950601 already OK.
# INFO:root:All ODFs for 0153950601.tar.gz have been extracted!
# INFO:root:Folder structure for 0153950701 already OK.
# INFO:root:All ODFs for 0153950701.tar.gz have been extracted!
# INFO:root:Folder structure for 0153950801 already OK.
# INFO:root:All ODFs for 0153950801.tar.gz have been extracted!
# INFO:root:Folder structure for 0153951201 already OK.
# INFO:root:All ODFs for 0153951201.tar.gz have been extracted!
# INFO:root:Folder structure for 0153951301 already OK.
# INFO:root:All ODFs for 0153951301.tar.gz have been extracted!
# INFO:root:Folder structure for 0158970101 already OK.
# INFO:root:All ODFs for 0158970101.tar.gz have been extracted!
# INFO:root:Folder structure for 0158970201 already OK.
# INFO:root:All ODFs for 0158970201.tar.gz have been extracted!
# INFO:root:Folder structure for 0158970701 already OK.
# INFO:root:All ODFs for 0158970701.tar.gz have been extracted!
# INFO:root:Folder structure for 0158971201 already OK.
# INFO:root:All ODFs for 0158971201.tar.gz have been extracted!
# INFO:root:Folder structure for 0158971301 already OK.
# INFO:root:All ODFs for 0158971301.tar.gz have been extracted!
# INFO:root:Folder structure for 0162960101 already OK.
# INFO:root:All ODFs for 0162960101.tar.gz have been extracted!
# INFO:root:Folder structure for 0302180101 already OK.
# INFO:root:All ODFs for 0302180101.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080101 already OK.
# INFO:root:All ODFs for 0411080101.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080201 already OK.
# INFO:root:All ODFs for 0411080201.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080301 already OK.
# INFO:root:All ODFs for 0411080301.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080401 already OK.
# INFO:root:All ODFs for 0411080401.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080501 already OK.
# INFO:root:All ODFs for 0411080501.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080701 already OK.
# INFO:root:All ODFs for 0411080701.tar.gz have been extracted!
# INFO:root:Folder structure for 0411080801 already OK.
# INFO:root:All ODFs for 0411080801.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081301 already OK.
# INFO:root:All ODFs for 0411081301.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081401 already OK.
# INFO:root:All ODFs for 0411081401.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081501 already OK.
# INFO:root:All ODFs for 0411081501.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081601 already OK.
# INFO:root:All ODFs for 0411081601.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081701 already OK.
# INFO:root:All ODFs for 0411081701.tar.gz have been extracted!
# INFO:root:Folder structure for 0411081901 already OK.
# INFO:root:All ODFs for 0411081901.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082001 already OK.
# INFO:root:All ODFs for 0411082001.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082101 already OK.
# INFO:root:All ODFs for 0411082101.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082201 already OK.
# INFO:root:All ODFs for 0411082201.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082301 already OK.
# INFO:root:All ODFs for 0411082301.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082401 already OK.
# INFO:root:All ODFs for 0411082401.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082501 already OK.
# INFO:root:All ODFs for 0411082501.tar.gz have been extracted!
# INFO:root:Folder structure for 0411082701 already OK.
# INFO:root:All ODFs for 0411082701.tar.gz have been extracted!
# INFO:root:Folder structure for 0411083201 already OK.
# INFO:root:All ODFs for 0411083201.tar.gz have been extracted!
# INFO:root:Folder structure for 0502030101 already OK.
# INFO:root:All ODFs for 0502030101.tar.gz have been extracted!
# INFO:root:Folder structure for 0510610101 already OK.
# INFO:root:All ODFs for 0510610101.tar.gz have been extracted!
# INFO:root:Folder structure for 0510610201 already OK.
# INFO:root:All ODFs for 0510610201.tar.gz have been extracted!
# INFO:root:Folder structure for 0560980101 already OK.
# INFO:root:All ODFs for 0560980101.tar.gz have been extracted!
# INFO:root:Folder structure for 0560983301 already OK.
# INFO:root:All ODFs for 0560983301.tar.gz have been extracted!
# INFO:root:Folder structure for 0656380101 already OK.
# INFO:root:All ODFs for 0656380101.tar.gz have been extracted!
# INFO:root:Folder structure for 0656380601 already OK.
# INFO:root:All ODFs for 0656380601.tar.gz have been extracted!
# INFO:root:Folder structure for 0656380701 already OK.
# INFO:root:All ODFs for 0656380701.tar.gz have been extracted!
# INFO:root:Folder structure for 0656380801 already OK.
# INFO:root:All ODFs for 0656380801.tar.gz have been extracted!
# INFO:root:Folder structure for 0656381301 already OK.
# INFO:root:All ODFs for 0656381301.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800101 already OK.
# INFO:root:All ODFs for 0658800101.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800301 already OK.
# INFO:root:All ODFs for 0658800301.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800501 already OK.
# INFO:root:All ODFs for 0658800501.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800601 already OK.
# INFO:root:All ODFs for 0658800601.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800701 already OK.
# INFO:root:All ODFs for 0658800701.tar.gz have been extracted!
# INFO:root:Folder structure for 0658800801 already OK.
# INFO:root:All ODFs for 0658800801.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801201 already OK.
# INFO:root:All ODFs for 0658801201.tar.gz have been extracted!
# INFO:root:Folder structure for 0136541001 already OK.
# INFO:root:All ODFs for 0136541001.tar.gz have been extracted!
# INFO:root:Folder structure for 0136541101 already OK.
# INFO:root:All ODFs for 0136541101.tar.gz have been extracted!
# INFO:root:Folder structure for 0136541201 already OK.
# INFO:root:All ODFs for 0136541201.tar.gz have been extracted!
# INFO:root:Folder structure for 0670920401 already OK.
# INFO:root:All ODFs for 0670920401.tar.gz have been extracted!
# INFO:root:Folder structure for 0670920301 already OK.
# INFO:root:All ODFs for 0670920301.tar.gz have been extracted!
# INFO:root:Folder structure for 0670920501 already OK.
# INFO:root:All ODFs for 0670920501.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801301 already OK.
# INFO:root:All ODFs for 0658801301.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801401 already OK.
# INFO:root:All ODFs for 0658801401.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801501 already OK.
# INFO:root:All ODFs for 0658801501.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801601 already OK.
# INFO:root:All ODFs for 0658801601.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801701 already OK.
# INFO:root:All ODFs for 0658801701.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801801 already OK.
# INFO:root:All ODFs for 0658801801.tar.gz have been extracted!
# INFO:root:Folder structure for 0658801901 already OK.
# INFO:root:All ODFs for 0658801901.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802001 already OK.
# INFO:root:All ODFs for 0658802001.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802101 already OK.
# INFO:root:All ODFs for 0658802101.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802201 already OK.
# INFO:root:All ODFs for 0658802201.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802301 already OK.
# INFO:root:All ODFs for 0658802301.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802401 already OK.
# INFO:root:All ODFs for 0658802401.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802501 already OK.
# INFO:root:All ODFs for 0658802501.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802601 already OK.
# INFO:root:All ODFs for 0658802601.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802701 already OK.
# INFO:root:All ODFs for 0658802701.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802801 already OK.
# INFO:root:All ODFs for 0658802801.tar.gz have been extracted!
# INFO:root:Folder structure for 0658802901 already OK.
# INFO:root:All ODFs for 0658802901.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780101 already OK.
# INFO:root:All ODFs for 0791780101.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780201 already OK.
# INFO:root:All ODFs for 0791780201.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780501 already OK.
# INFO:root:All ODFs for 0791780501.tar.gz have been extracted!
# INFO:root:Folder structure for 0791781001 already OK.
# INFO:root:All ODFs for 0791781001.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780601 already OK.
# INFO:root:All ODFs for 0791780601.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780901 already OK.
# INFO:root:All ODFs for 0791780901.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780701 already OK.
# INFO:root:All ODFs for 0791780701.tar.gz have been extracted!
# INFO:root:Folder structure for 0791780801 already OK.
# INFO:root:All ODFs for 0791780801.tar.gz have been extracted!
# INFO:root:Folder structure for 0791781401 already OK.
# INFO:root:All ODFs for 0791781401.tar.gz have been extracted!
# INFO:root:Folder structure for 0791781201 already OK.
# INFO:root:All ODFs for 0791781201.tar.gz have been extracted!
# INFO:root:Folder structure for 0791781101 already OK.
# INFO:root:All ODFs for 0791781101.tar.gz have been extracted!
# INFO:root:Folder structure for 0791782001 already OK.
# INFO:root:All ODFs for 0791782001.tar.gz have been extracted!
# INFO:root:Folder structure for 0810860201 already OK.
# INFO:root:All ODFs for 0810860201.tar.gz have been extracted!
# INFO:root:Folder structure for 0810860701 already OK.
# INFO:root:All ODFs for 0810860701.tar.gz have been extracted!
# INFO:root:Folder structure for 0845000901 already OK.
# ERROR:root:An error has occurred with tar 0845000901.tar.gz.
# INFO:root:Folder structure for 0810862501 already OK.
# INFO:root:All ODFs for 0810862501.tar.gz have been extracted!
# INFO:root:Folder structure for 0850380301 already OK.
# ERROR:root:An error has occurred with tar 0850380301.tar.gz.
# INFO:root:Folder structure for 0850380401 already OK.
# ERROR:root:An error has occurred with tar 0850380401.tar.gz.
